# %% [markdown]
# ### 13장3,4 14장5 pandas를 사용하여 dataframe으로 풀기

# %%
import pandas as pd

# %% [markdown]
# ### chapter13 3번

# %%
df = pd.read_csv('high_school_2019.csv')
df
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수
# 0          149         5       143
# 1          228         8       270
# ...

# %%
df1 = df.iloc[:, [3,5,7]]
df1
# Out:
#        1학년 학생수   2학년 학생수   3학년 학생수
# 0          150       149       143
# 1          239       228       270
# 2          182       174       169
# 3          282       262       288
# 4          210       183       221
# ...        ...       ...       ...
# 2393       279       279       305
# 2394       151       141       135
# 2395        76        91       103
# 2396        99        95        92
# 2397       116        98       126
#
# [2398 rows x 3 columns]

# %%
df['총학생수'] = df1.sum(axis=1)   #합계 추가
df
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수  총학생수
# 0          149         5       143   442
# 1          228         8       270   737
# ...

# %% [markdown]
# ### Chapter13 4번

# %%
df2 = df.iloc[:, [3,5,7]]
df2
# Out:
#        1학년 학생수   2학년 학생수   3학년 학생수
# 0          150       149       143
# 1          239       228       270
# 2          182       174       169
# 3          282       262       288
# 4          210       183       221
# ...        ...       ...       ...
# 2393       279       279       305
# 2394       151       141       135
# 2395        76        91       103
# 2396        99        95        92
# 2397       116        98       126
#
# [2398 rows x 3 columns]

# %%
df3 = df2.sum(axis=0)
df3
# Out:
#  1학년 학생수    463400
#  2학년 학생수    444714
#  3학년 학생수    500698
# dtype: int64

# %%
# Matplotlib 사용과 한글 처리를 위한 Code
import matplotlib as mpl 
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False 
mpl.rc('font', family='Malgun Gothic')   
# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["font.size"] = 14

# %%
df3.index = ['1학년', '2학년','3학년']   #이름변경
df3
# Out:
# 1학년    463400
# 2학년    444714
# 3학년    500698
# dtype: int64

# %%
df3.plot.bar()
plt.title("전국 고등학교 학년별 총 학생수")
plt.show()

# %% [markdown]
# ### Chapter14 5번

# %%
df5 = pd.read_csv('population_age_2020.csv')
df5
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 4     광주   1456121   125396   162728   207554   191432   244903   234048
# 5     대전   1473125   120476   151861   212143   199106   242381   243526
# 6     울산   1145710   103399   115623   147745   158271   190698   211255
# 7     세종    343788    47454    40574    36273    61442    65714    42907
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# ...

# %%
df5 = df5.sort_values(by=['100세 이상'],axis=0,ascending=False)  #ascending=False 내림차순
df5
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 14  경상북도   2658956   198214   233506   291097   303472   390995   464427
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# 13  전라남도   1861894   137868   172888   202760   193083   265366   317226
# 12  전라북도   1815112   135297   180675   212339   195971   274471   303074
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 15  경상남도   3358828   282751   331566   384750   418383   543911   585186
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# ...

# %%
df5 = df5[['지역','100세 이상','총인구수']]
df5
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 8    경기도     4010  13265377
# 1     부산     1807   3410925
# 14  경상북도      960   2658956
# 3     인천      908   2954955
# 11  충청남도      885   2120995
# 13  전라남도      822   1861894
# 12  전라북도      817   1815112
# 9    강원도      803   1539521
# 15  경상남도      739   3358828
# 2     대구      694   2432883
# 10  충청북도      541   1598599
# 4     광주      405   1456121
# 5     대전      339   1473125
# 16   제주도      266    670876
# 6     울산      160   1145710
# 7     세종       55    343788

# %%
df5 = df5.reset_index(drop=True)  #index 다시 재설정
df5
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 1    경기도     4010  13265377
# 2     부산     1807   3410925
# 3   경상북도      960   2658956
# 4     인천      908   2954955
# 5   충청남도      885   2120995
# 6   전라남도      822   1861894
# 7   전라북도      817   1815112
# 8    강원도      803   1539521
# 9   경상남도      739   3358828
# 10    대구      694   2432883
# 11  충청북도      541   1598599
# 12    광주      405   1456121
# 13    대전      339   1473125
# 14   제주도      266    670876
# 15    울산      160   1145710
# 16    세종       55    343788
